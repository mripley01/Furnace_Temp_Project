# %% [markdown]
# <a href="https://colab.research.google.com/github/mripley01/Furnace_Temp_Project/blob/main/Furnace_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Import

# %%
import pandas as pd

url = (
    "https://raw.githubusercontent.com/mripley01/"
    "Furnace_Temp_Project/main/Raw_Furnace_Data.csv"
)

df = pd.read_csv(url)
df.head()
# Out:
#             DATE_TIME DSF  MACHINE_IDENTIFIER  TEMP_SETPOINT  \
# 0  8/28/26 3:00:01 PM   Y              547560           4060
# 1  8/28/26 3:02:01 PM   Y              547560           4060
# 2  8/28/26 3:04:01 PM   Y              547560           4060
# 3  8/28/26 3:06:01 PM   Y              547560           4060
# 4  8/28/26 3:08:00 PM   Y              547560           4060
#
#    CONTROLLER_TC_TEMP  PERCENT_POWER  ZONE_1_TC_TEMP  ZONE_2_TC_TEMP  \
# 0                3915            100            3897            3891
# 1                3936            100            3918            3912
# 2                3953            100            3935            3929
# 3                3967            100            3950            3943
# 4                3979            100            3962            3955
#
#    ZONE_3_TC_TEMP  ZONE_4_TC_TEMP  ZONE_5_TC_TEMP
# 0            3899            3892            3898
# 1            3921            3912            3919
# ...
